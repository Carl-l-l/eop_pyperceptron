# %%
import numpy as np

# %%
class Perceptron:
    # Perceptron class, implementing inputs, weights, learning
    def __init__(self, learning_rate, inputs, init_weight, ):
        self.learning_rate = learning_rate
        self.inputs = inputs
        self.init_weight = init_weight
        self.weights = np.array([init_weight] * len(inputs))
        self.output = 0

    
    def get_learning_rate(self):
        return self.learning_rate
    
    def get_inputs(self):
        return self.inputs
    
    def get_weights(self):
        return self.weights
    
    def predict(self):
        pass

    def train(self, target):
        pass
